# %% [markdown]
# # TPH 20/08

# %%
# %matplotlib notebook
import control
import numpy as np
import scipy as sp
from scipy import signal
from matplotlib import pylab as plt
from ipywidgets import *
from IPython.display import display
from IPython.html import widgets
plt.style.use('ggplot')
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def polymul(arrays):
    salida = [1]
    for i in arrays:
        salida = np.polymul(salida,i)
    return salida

# %% [markdown]
# ## Ej1 a

# %%
sysA1 = signal.lti([1,0.1],polymul(([1,0],[1,2],[1,0.01])));
control.root_locus(sysA1, kvect= np.linspace(0.001,100,10000));
plt.title("Ejercicio A1")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sysA2 = signal.lti([1,0.1],polymul(([1,0.01],[1,0],[1,2],[1,5])));
control.root_locus(sysA2, kvect= np.logspace(-3,2,10000));
plt.title("Ejercicio A2")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sysA3 = signal.lti([1,0.1],polymul(([1,0],[1,2],[1,5],[1,0])))
control.root_locus(sysA3, kvect= np.logspace(-3,2,10000))
plt.title("Ejercicio A3")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A = 1
sysA4 = signal.lti(polymul(([1],[A,A*2.93])),polymul(([1,0],[1,2],[1,5.46])))
control.root_locus(sysA4, kvect= np.logspace(-3,2,10000))
plt.title("Ejercicio A4")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A = 1
sysA5 = signal.lti(polymul(([1],[A,A*4])),polymul(([1,0],[1,2],[1,8])))
control.root_locus(sysA5, kvect= np.logspace(-3,2,10000))
plt.title("Ejercicio A5")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A = 1
sysA6 = signal.lti(polymul(([1],[0.4,0.4*8])),polymul(([1,0],[1,2])))
control.root_locus(sysA6, kvect= np.logspace(-3,2,10000))
plt.title("Ejercicio A6")
# Out:
# <img src="data:image/png;base64,..." width="1119">

# %%
K = 1
Kc = 1
sysA7 = signal.lti(polymul(([K],[Kc],[1,2],[1,8])),   polymul(([1,0],[1,2],[1,0])))
control.root_locus(sysA7, kvect= np.logspace(-3,2,10000))
plt.title("Ejercicio A7")
# Out:
# <img src="data:image/png;base64,..." width="1153">

# %%
K = 1
sysA8 = signal.lti(polymul(([K],[1])),   polymul(([1,0],[1,4],[1,10])))
control.root_locus(sysA8, kvect= np.logspace(-3,2,10000))
plt.title("Ejercicio A8")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Ks = 1
sysA9 = signal.lti(polymul(([Ks],[1,2])),   polymul(([1,-2.9,14.35,0],[1,4.9])))
control.root_locus(sysA9, kvect= np.logspace(-4,4,1000))
plt.title("Ejercicio A9")
# Out:
# <img src="data:image/png;base64,..." width="1137">

# %%
K = 1
sysA10a = signal.lti(polymul(([K],[1])),   polymul(([1,0],[1,4],[1,10])))
control.root_locus(sysA10a, kvect= np.logspace(-3,2,10000))
plt.title("Ejercicio A10a")

# %%
multiplicar(([1,1],[1,0],[1,0]))
# Out:
# array([1, 1, 0, 0])
