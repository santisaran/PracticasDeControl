# %% [markdown]
# # TPH 20/08

# %%
# %matplotlib notebook
import control
import numpy as np
import scipy as sp
from scipy import signal
from matplotlib import pylab as plt
from ipywidgets import *
from IPython.display import display
from IPython.html import widgets
plt.style.use('ggplot')
# Out:
# /usr/local/lib/python3.4/dist-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ## Ej1 a

# %%
sys5_8 = signal.lti([1,3],np.polymul([1,0],np.polymul([1,2],[1,5])));
control.root_locus(sys5_8, kvect= np.linspace(0.001,100,10000));
# Out:
# <img src="data:image/png;base64,..." width="936">

# %%
k = 1
ej6_1 = signal.lti([1,0.1],np.polymul([1,0],np.polymul([1,0.01],[1,2])))
control.root_locus(ej6_1, kvect= np.logspace(-4,2,10000))

# %%
k = 1
ej6_2 = signal.lti([1,2],[1,2,3])
control.root_locus(ej6_2, kvect= np.linspace(0.001,100,10000))

# %%
k = 1
ej14 = signal.lti([1],np.polymul([1,2],np.polymul([1,4],[1,6,18])))
control.root_locus(ej14, kvect= np.logspace(-4,4,10000))

# %%
ej13 = signal.lti([1],np.polymul([1,2,1],[1,2,5]))
control.root_locus(ej13, kvect= np.logspace(-4,4,10000))

# %%
ejClase = signal.lti([1],np.polymul([1,6,9],[1,6,18]))
control.root_locus(ejClase, kvect= np.logspace(-3,3,10000))

# %%
signal.zpk2tf([],[0,2,5],1)

# %%
sys = signal.lti([1],[1,-7,10,0])

# %%
plt.plot(np.log10(sys.bode()[0]),np.log10(sys.bode()[1]))
